# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_csv('example')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('example',index=False)

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input

# %%
# In terminal: conda install xlrd  or pip install xlrd 
pd.read_excel('Excel_Sample.xlsx',sheetname='Sheet1')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('Excel_Sample2.xlsx',sheet_name='NewSheet')

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# ### HTML Input
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
# Check installs 
import lxml
import html5lib
import bs4

# %%
# Pandas will try to find every table element in HTML file
df = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
df[0].head()
# Out:
#   \n            Bank NameBank\n         \n            CityCity\n          \
# 0                         Citizens Bank                         Sac City
# 1              Heartland Tri-State Bank                          Elkhart
# 2                   First Republic Bank                    San Francisco
# 3                        Signature Bank                         New York
# 4                   Silicon Valley Bank                      Santa Clara
#
#   \n            StateSt\n          \n            CertCert\n          \
# 0                              IA                              8758
# 1                              KS                             25851
# 2                              CA                             59017
# 3                              NY                             57053
# 4                              CA                             24735
#
#   \n            Acquiring InstitutionAI\n          \
# 0                       Iowa Trust & Savings Bank
# 1                          Dream First Bank, N.A.
# 2                       JPMorgan Chase Bank, N.A.
# 3                             Flagstar Bank, N.A.
# 4             First–Citizens Bank & Trust Company
#
#   \n            Closing DateClosing\n          \
# 0                            November 3, 2023
# 1                               July 28, 2023
# 2                                 May 1, 2023
# 3                              March 12, 2023
# 4                              March 10, 2023
#
#    \n            FundFund\n
# 0                             10545
# 1                             10544
# 2                             10543
# 3                             10540
# 4                             10539

# %% [markdown]
# ____

# %% [markdown]
# _____
# _____
# # SQL (Optional)
#
# * Note: If you are completely unfamiliar with SQL you can check out my other course: "Complete SQL Bootcamp" to learn SQL.

# %% [markdown]
# The pandas.io.sql module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependency on DB-specific API. Database abstraction is provided by SQLAlchemy if installed. In addition you will need a driver library for your database. Examples of such drivers are psycopg2 for PostgreSQL or pymysql for MySQL. For SQLite this is included in Python’s standard library by default. You can find an overview of supported drivers for each SQL dialect in the SQLAlchemy docs.
#
#
# If SQLAlchemy is not installed, a fallback is only provided for sqlite (and for mysql for backwards compatibility, but this is deprecated and will be removed in a future version). This mode requires a Python database adapter which respect the Python DB-API.
#
# See also some cookbook examples for some advanced strategies.
#
# The key functions are:
#
# * read_sql_table(table_name, con[, schema, ...])
#     * Read SQL database table into a DataFrame.
# * read_sql_query(sql, con[, index_col, ...])
#     * Read SQL query into a DataFrame.
# * read_sql(sql, con[, index_col, ...])
#     * Read SQL query or database table into a DataFrame.
# * DataFrame.to_sql(name, con[, flavor, ...])
#     * Write records stored in a DataFrame to a SQL database.

# %%
from sqlalchemy import create_engine

# %%
# Build a small SQL engine that will be temporarily held in memory 
engine = create_engine('sqlite:///:memory:')

# %%
df[0].to_sql('data1', engine, if_exists='replace', chunksize=10)

# %%
sql_df = pd.read_sql('data1',con=engine)

# %%
sql_df
# Out:
#      index              \n            Bank NameBank\n          \
# 0        0                                      Citizens Bank
# 1        1                           Heartland Tri-State Bank
# 2        2                                First Republic Bank
# 3        3                                     Signature Bank
# 4        4                                Silicon Valley Bank
# 5        5                                  Almena State Bank
# 6        6                         First City Bank of Florida
# 7        7                               The First State Bank
# 8        8                                 Ericson State Bank
# 9        9                   City National Bank of New Jersey
# 10      10                                      Resolute Bank
# 11      11                              Louisa Community Bank
# 12      12                               The Enloe State Bank
# 13      13                Washington Federal Bank for Savings
# 14      14    The Farmers and Merchants State Bank of Argonia
# 15      15                                Fayette County Bank
# 16      16  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...
# 17      17                                     First NBC Bank
# 18      18                                      Proficio Bank
# 19      19                      Seaway Bank and Trust Company
# 20      20                             Harvest Community Bank
# 21      21                                        Allied Bank
# 22      22                       The Woodbury Banking Company
# 23      23                             First CornerStone Bank
# 24      24                                 Trust Company Bank
# 25      25                         North Milwaukee State Bank
# 26      26                             Hometown National Bank
# 27      27                                The Bank of Georgia
# 28      28                                       Premier Bank
# 29      29                                     Edgebrook Bank
# ..     ...                                                ...
# 538    538                                  ANB Financial, NA
# 539    539                                          Hume Bank
# 540    540                             Douglass National Bank
# 541    541                                  Miami Valley Bank
# 542    542                                            NetBank
# 543    543                          Metropolitan Savings Bank
# 544    544                                    Bank of Ephraim
# 545    545                                      Reliance Bank
# 546    546              Guaranty National Bank of Tallahassee
# 547    547                                Dollar Savings Bank
# 548    548                               Pulaski Savings Bank
# 549    549              First National Bank of Blanchardville
# 550    550                              Southern Pacific Bank
# 551    551                        Farmers Bank of Cheneyville
# 552    552                                      Bank of Alamo
# 553    553             AmTrade International Bank  En Español
# 554    554                     Universal Federal Savings Bank
# 555    555                       Connecticut Bank of Commerce
# 556    556                                   New Century Bank
# 557    557                              Net 1st National Bank
# 558    558                                       NextBank, NA
# 559    559                           Oakwood Deposit Bank Co.
# 560    560                              Bank of Sierra Blanca
# 561    561                      Hamilton Bank, NA  En Español
# 562    562                             Sinclair National Bank
# 563    563                                 Superior Bank, FSB
# 564    564                                Malta National Bank
# 565    565                    First Alliance Bank & Trust Co.
# 566    566                  National State Bank of Metropolis
# 567    567                                   Bank of Honolulu
#
#     \n            CityCity\n         \n            StateSt\n          \
# 0                           Sac City                              IA
# 1                            Elkhart                              KS
# 2                      San Francisco                              CA
# 3                           New York                              NY
# 4                        Santa Clara                              CA
# 5                             Almena                              KS
# 6                  Fort Walton Beach                              FL
# 7                      Barboursville                              WV
# 8                            Ericson                              NE
# 9                             Newark                              NJ
# 10                            Maumee                              OH
# 11                            Louisa                              KY
# 12                            Cooper                              TX
# 13                           Chicago                              IL
# 14                           Argonia                              KS
# 15                        Saint Elmo                              IL
# 16                         Milwaukee                              WI
# 17                       New Orleans                              LA
# 18                Cottonwood Heights                              UT
# 19                           Chicago                              IL
# 20                        Pennsville                              NJ
# 21                          Mulberry                              AR
# 22                          Woodbury                              GA
# 23                   King of Prussia                              PA
# 24                           Memphis                              TN
# 25                         Milwaukee                              WI
# 26                          Longview                              WA
# 27                    Peachtree City                              GA
# 28                            Denver                              CO
# 29                           Chicago                              IL
# ..                               ...                             ...
# 538                      Bentonville                              AR
# 539                             Hume                              MO
# 540                      Kansas City                              MO
# 541                         Lakeview                              OH
# 542                       Alpharetta                              GA
# 543                       Pittsburgh                              PA
# 544                          Ephraim                              UT
# 545                     White Plains                              NY
# 546                      Tallahassee                              FL
# 547                           Newark                              NJ
# 548                     Philadelphia                              PA
# 549                   Blanchardville                              WI
# 550                         Torrance                              CA
# 551                      Cheneyville                              LA
# 552                            Alamo                              TN
# 553                          Atlanta                              GA
# 554                          Chicago                              IL
# 555                         Stamford                              CT
# 556                  Shelby Township                              MI
# 557                       Boca Raton                              FL
# 558                          Phoenix                              AZ
# 559                          Oakwood                              OH
# 560                    Sierra Blanca                              TX
# 561                            Miami                              FL
# 562                         Gravette                              AR
# 563                         Hinsdale                              IL
# 564                            Malta                              OH
# 565                       Manchester                              NH
# 566                       Metropolis                              IL
# 567                         Honolulu                              HI
#
#      \n            CertCert\n          \
# 0                                8758
# 1                               25851
# 2                               59017
# 3                               57053
# 4                               24735
# 5                               15426
# 6                               16748
# 7                               14361
# 8                               18265
# 9                               21111
# 10                              58317
# 11                              58112
# 12                              10716
# 13                              30570
# 14                              17719
# 15                               1802
# 16                              30003
# 17                              58302
# 18                              35495
# 19                              19328
# 20                              34951
# 21                                 91
# 22                              11297
# 23                              35312
# 24                               9956
# 25                              20364
# 26                              35156
# 27                              35259
# 28                              34112
# 29                              57772
# ..                                ...
# 538                             33901
# 539                              1971
# 540                             24660
# 541                             16848
# 542                             32575
# 543                             35353
# 544                              1249
# 545                             26778
# 546                             26838
# 547                             31330
# 548                             27203
# 549                             11639
# 550                             27094
# 551                             16445
# 552                              9961
# 553                             33784
# 554                             29355
# 555                             19183
# 556                             34979
# 557                             26652
# 558                             22314
# 559                              8966
# 560                             22002
# 561                             24382
# 562                             34248
# 563                             32646
# 564                              6629
# 565                             34264
# 566                              3815
# 567                             21029
#
#     \n            Acquiring InstitutionAI\n          \
# 0                         Iowa Trust & Savings Bank
# 1                            Dream First Bank, N.A.
# 2                         JPMorgan Chase Bank, N.A.
# 3                               Flagstar Bank, N.A.
# 4               First–Citizens Bank & Trust Company
# 5                                       Equity Bank
# 6                         United Fidelity Bank, fsb
# 7                                    MVB Bank, Inc.
# 8                        Farmers and Merchants Bank
# 9                                   Industrial Bank
# 10                               Buckeye State Bank
# 11                Kentucky Farmers Bank Corporation
# 12                               Legend Bank, N. A.
# 13                               Royal Savings Bank
# 14                                      Conway Bank
# 15                        United Fidelity Bank, fsb
# 16              First-Citizens Bank & Trust Company
# 17                                     Whitney Bank
# 18                                Cache Valley Bank
# 19                              State Bank of Texas
# 20              First-Citizens Bank & Trust Company
# 21                                     Today's Bank
# 22                                      United Bank
# 23              First-Citizens Bank & Trust Company
# 24                       The Bank of Fayette County
# 25              First-Citizens Bank & Trust Company
# 26                                   Twin City Bank
# 27                                    Fidelity Bank
# 28                        United Fidelity Bank, fsb
# 29                         Republic Bank of Chicago
# ..                                              ...
# 538                  Pulaski Bank and Trust Company
# 539                                   Security Bank
# 540                  Liberty Bank and Trust Company
# 541                    The Citizens Banking Company
# 542                                      ING DIRECT
# 543             Allegheny Valley Bank of Pittsburgh
# 544                                   Far West Bank
# 545                                Union State Bank
# 546                         Hancock Bank of Florida
# 547                                     No Acquirer
# 548                                  Earthstar Bank
# 549                                   The Park Bank
# 550                                       Beal Bank
# 551                       Sabine State Bank & Trust
# 552                                     No Acquirer
# 553                                     No Acquirer
# 554                          Chicago Community Bank
# 555                              Hudson United Bank
# 556                                     No Acquirer
# 557                                  Bank Leumi USA
# 558                                     No Acquirer
# 559                  The State Bank & Trust Company
# 560                The Security State Bank of Pecos
# 561                Israel Discount Bank of New York
# 562                              Delta Trust & Bank
# 563                           Superior Federal, FSB
# 564                               North Valley Bank
# 565             Southern New Hampshire Bank & Trust
# 566                         Banterra Bank of Marion
# 567                              Bank of the Orient
#
#     \n            Closing DateClosing\n          \
# 0                              November 3, 2023
# 1                                 July 28, 2023
# 2                                   May 1, 2023
# 3                                March 12, 2023
# 4                                March 10, 2023
# 5                              October 23, 2020
# 6                              October 16, 2020
# 7                                 April 3, 2020
# 8                             February 14, 2020
# 9                              November 1, 2019
# 10                             October 25, 2019
# 11                             October 25, 2019
# 12                                 May 31, 2019
# 13                            December 15, 2017
# 14                             October 13, 2017
# 15                                 May 26, 2017
# 16                                  May 5, 2017
# 17                               April 28, 2017
# 18                                March 3, 2017
# 19                             January 27, 2017
# 20                             January 13, 2017
# 21                           September 23, 2016
# 22                              August 19, 2016
# 23                                  May 6, 2016
# 24                               April 29, 2016
# 25                               March 11, 2016
# 26                              October 2, 2015
# 27                              October 2, 2015
# 28                                July 10, 2015
# 29                                  May 8, 2015
# ..                                          ...
# 538                                 May 9, 2008
# 539                               March 7, 2008
# 540                            January 25, 2008
# 541                             October 4, 2007
# 542                          September 28, 2007
# 543                            February 2, 2007
# 544                               June 25, 2004
# 545                              March 19, 2004
# 546                              March 12, 2004
# 547                           February 14, 2004
# 548                           November 14, 2003
# 549                                 May 9, 2003
# 550                            February 7, 2003
# 551                           December 17, 2002
# 552                            November 8, 2002
# 553                          September 30, 2002
# 554                               June 27, 2002
# 555                               June 26, 2002
# 556                              March 28, 2002
# 557                               March 1, 2002
# 558                            February 7, 2002
# 559                            February 1, 2002
# 560                            January 18, 2002
# 561                            January 11, 2002
# 562                           September 7, 2001
# 563                               July 27, 2001
# 564                                 May 3, 2001
# 565                            February 2, 2001
# 566                           December 14, 2000
# 567                            October 13, 2000
#
#      \n            FundFund\n
# 0                               10545
# 1                               10544
# 2                               10543
# 3                               10540
# 4                               10539
# 5                               10538
# 6                               10537
# 7                               10536
# 8                               10535
# 9                               10534
# 10                              10533
# 11                              10532
# 12                              10531
# 13                              10530
# 14                              10529
# 15                              10528
# 16                              10527
# 17                              10526
# 18                              10525
# 19                              10524
# 20                              10523
# 21                              10522
# 22                              10521
# 23                              10520
# 24                              10519
# 25                              10518
# 26                              10517
# 27                              10516
# 28                              10515
# 29                              10514
# ..                                ...
# 538                             10005
# 539                             10004
# 540                             10003
# 541                             10002
# 542                             10001
# 543                             10000
# 544                              4665
# 545                              4664
# 546                              4663
# 547                              6006
# 548                              4662
# 549                              4661
# 550                              4660
# 551                              4659
# 552                              4658
# 553                              4657
# 554                              6005
# 555                              4656
# 556                              4655
# 557                              4654
# 558                              4653
# 559                              4652
# 560                              4651
# 561                              4650
# 562                              4649
# 563                              6004
# 564                              4648
# 565                              4647
# 566                              4646
# 567                              4645
#
# [568 rows x 8 columns]

# %% [markdown]
# # Great Job!
